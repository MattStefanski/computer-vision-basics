# %% [markdown]
# <a href="https://colab.research.google.com/github/MattStefanski/computer-vision-basics/blob/master/Initro_Google_Colab_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

import cv2

# %%
img=cv2.imread('pic1.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F38F3071240>
